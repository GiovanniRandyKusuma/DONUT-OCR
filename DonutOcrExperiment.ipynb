# %%
# !pip install transformers==4.25.1
# !pip install pytorch-lightning==1.8.5
# !pip install timm==0.5.4
# !pip install gradio
# !pip install donut-python
# !pip install ipywidgets
# Out:
# Requirement already satisfied: transformers==4.25.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (4.25.1)
# Requirement already satisfied: filelock in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers==4.25.1) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers==4.25.1) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers==4.25.1) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers==4.25.1) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers==4.25.1) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers==4.25.1) (2023.12.25)
# Requirement already satisfied: requests in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers==4.25.1) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers==4.25.1) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers==4.25.1) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.25.1) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.25.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->transformers==4.25.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->transformers==4.25.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->transformers==4.25.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->transformers==4.25.1) (2023.11.17)
# DEPRECATION: pytorch-lightning 1.6.4 has a non-standard dependency specifier torch>=1.8.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Collecting pytorch-lightning==1.8.5
#   Using cached pytorch_lightning-1.8.5-py3-none-any.whl (800 kB)
# Requirement already satisfied: numpy>=1.17.2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning==1.8.5) (1.24.4)
# Requirement already satisfied: torch>=1.9.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning==1.8.5) (2.1.2)
# Requirement already satisfied: tqdm>=4.57.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning==1.8.5) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning==1.8.5) (6.0.1)
# Requirement already satisfied: fsspec>2021.06.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (2023.10.0)
# Collecting tensorboardX>=2.2 (from pytorch-lightning==1.8.5)
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torchmetrics>=0.7.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning==1.8.5) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning==1.8.5) (23.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning==1.8.5) (4.9.0)
# Requirement already satisfied: lightning-utilities!=0.4.0,>=0.3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning==1.8.5) (0.10.0)
# Requirement already satisfied: requests in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (3.9.1)
# Requirement already satisfied: setuptools in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from lightning-utilities!=0.4.0,>=0.3.0->pytorch-lightning==1.8.5) (68.2.2)
# Requirement already satisfied: protobuf>=3.20 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from tensorboardX>=2.2->pytorch-lightning==1.8.5) (3.20.1)
# Requirement already satisfied: filelock in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.5) (3.13.1)
# Requirement already satisfied: sympy in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.5) (1.12)
# Requirement already satisfied: networkx in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.5) (3.1)
# Requirement already satisfied: jinja2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.5) (3.1.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from jinja2->torch>=1.9.0->pytorch-lightning==1.8.5) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning==1.8.5) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from sympy->torch>=1.9.0->pytorch-lightning==1.8.5) (1.3.0)
# Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Installing collected packages: tensorboardX, pytorch-lightning
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 1.6.4
#     Uninstalling pytorch-lightning-1.6.4:
#       Successfully uninstalled pytorch-lightning-1.6.4
# Successfully installed pytorch-lightning-1.8.5 tensorboardX-2.6.2.2
# Requirement already satisfied: timm==0.5.4 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (0.5.4)
# Requirement already satisfied: torch>=1.4 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from timm==0.5.4) (2.1.2)
# Requirement already satisfied: torchvision in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from timm==0.5.4) (0.16.2)
# Requirement already satisfied: filelock in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.4->timm==0.5.4) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.4->timm==0.5.4) (4.9.0)
# Requirement already satisfied: sympy in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.4->timm==0.5.4) (1.12)
# Requirement already satisfied: networkx in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.4->timm==0.5.4) (3.1)
# Requirement already satisfied: jinja2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.4->timm==0.5.4) (3.1.2)
# Requirement already satisfied: fsspec in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.4->timm==0.5.4) (2023.10.0)
# Requirement already satisfied: numpy in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torchvision->timm==0.5.4) (1.24.4)
# Requirement already satisfied: requests in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torchvision->timm==0.5.4) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torchvision->timm==0.5.4) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from jinja2->torch>=1.4->timm==0.5.4) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->torchvision->timm==0.5.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->torchvision->timm==0.5.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->torchvision->timm==0.5.4) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->torchvision->timm==0.5.4) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from sympy->torch>=1.4->timm==0.5.4) (1.3.0)
# Requirement already satisfied: gradio in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (4.12.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (5.2.0)
# Requirement already satisfied: fastapi in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (0.108.0)
# Requirement already satisfied: ffmpy in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (0.3.1)
# Requirement already satisfied: gradio-client==0.8.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (0.8.0)
# Requirement already satisfied: httpx in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (0.26.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (0.20.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (3.7.4)
# Requirement already satisfied: numpy~=1.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (1.24.4)
# Requirement already satisfied: orjson~=3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (3.9.10)
# Requirement already satisfied: packaging in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (10.1.0)
# Requirement already satisfied: pydantic>=2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (2.5.3)
# Requirement already satisfied: pydub in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: semantic-version~=2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (4.9.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio) (0.25.0)
# Requirement already satisfied: fsspec in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio-client==0.8.0->gradio) (2023.10.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from gradio-client==0.8.0->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from altair<6.0,>=4.2.0->gradio) (4.20.0)
# Requirement already satisfied: toolz in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from matplotlib~=3.0->gradio) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from matplotlib~=3.0->gradio) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pydantic>=2.0->gradio) (2.14.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from typer[all]<1.0,>=0.9->gradio) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from typer[all]<1.0,>=0.9->gradio) (13.7.0)
# Requirement already satisfied: h11>=0.8 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: starlette<0.33.0,>=0.29.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from fastapi->gradio) (0.32.0.post1)
# Requirement already satisfied: anyio in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from httpx->gradio) (4.2.0)
# Requirement already satisfied: certifi in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from httpx->gradio) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from httpx->gradio) (1.0.2)
# Requirement already satisfied: idna in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from httpx->gradio) (3.6)
# Requirement already satisfied: sniffio in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.15.2)
# Requirement already satisfied: six>=1.5 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.17.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from anyio->httpx->gradio) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.1.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)
# Requirement already satisfied: donut-python in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (1.0.9)
# Requirement already satisfied: transformers>=4.11.3 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from donut-python) (4.25.1)
# Requirement already satisfied: timm in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from donut-python) (0.5.4)
# Requirement already satisfied: datasets[vision] in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from donut-python) (2.16.0)
# Requirement already satisfied: pytorch-lightning>=1.6.4 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from donut-python) (1.8.5)
# Requirement already satisfied: nltk in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from donut-python) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from donut-python) (0.1.99)
# Requirement already satisfied: zss in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from donut-python) (1.2.0)
# Requirement already satisfied: sconf>=0.2.3 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from donut-python) (0.2.5)
# Requirement already satisfied: numpy>=1.17.2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning>=1.6.4->donut-python) (1.24.4)
# Requirement already satisfied: torch>=1.9.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2.1.2)
# Requirement already satisfied: tqdm>=4.57.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning>=1.6.4->donut-python) (6.0.1)
# Requirement already satisfied: fsspec>2021.06.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning>=1.6.4->donut-python) (2023.10.0)
# Requirement already satisfied: tensorboardX>=2.2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2.6.2.2)
# Requirement already satisfied: torchmetrics>=0.7.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning>=1.6.4->donut-python) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning>=1.6.4->donut-python) (23.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.9.0)
# Requirement already satisfied: lightning-utilities!=0.4.0,>=0.3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pytorch-lightning>=1.6.4->donut-python) (0.10.0)
# Requirement already satisfied: ruamel.yaml in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from sconf>=0.2.3->donut-python) (0.18.5)
# Requirement already satisfied: munch in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from sconf>=0.2.3->donut-python) (4.0.0)
# Requirement already satisfied: filelock in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers>=4.11.3->donut-python) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers>=4.11.3->donut-python) (0.20.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers>=4.11.3->donut-python) (2023.12.25)
# Requirement already satisfied: requests in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers>=4.11.3->donut-python) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from transformers>=4.11.3->donut-python) (0.13.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from datasets[vision]->donut-python) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from datasets[vision]->donut-python) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from datasets[vision]->donut-python) (0.3.7)
# Requirement already satisfied: pandas in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from datasets[vision]->donut-python) (2.0.3)
# Requirement already satisfied: xxhash in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from datasets[vision]->donut-python) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from datasets[vision]->donut-python) (0.70.15)
# Requirement already satisfied: aiohttp in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from datasets[vision]->donut-python) (3.9.1)
# Requirement already satisfied: Pillow>=6.2.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from datasets[vision]->donut-python) (10.1.0)
# Requirement already satisfied: click in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from nltk->donut-python) (8.1.7)
# Requirement already satisfied: joblib in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from nltk->donut-python) (1.3.2)
# Requirement already satisfied: torchvision in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from timm->donut-python) (0.16.2)
# Requirement already satisfied: six in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from zss->donut-python) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp->datasets[vision]->donut-python) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp->datasets[vision]->donut-python) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp->datasets[vision]->donut-python) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp->datasets[vision]->donut-python) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp->datasets[vision]->donut-python) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from aiohttp->datasets[vision]->donut-python) (4.0.3)
# Requirement already satisfied: setuptools in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from lightning-utilities!=0.4.0,>=0.3.0->pytorch-lightning>=1.6.4->donut-python) (68.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->transformers>=4.11.3->donut-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->transformers>=4.11.3->donut-python) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->transformers>=4.11.3->donut-python) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from requests->transformers>=4.11.3->donut-python) (2023.11.17)
# Requirement already satisfied: protobuf>=3.20 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from tensorboardX>=2.2->pytorch-lightning>=1.6.4->donut-python) (3.20.1)
# Requirement already satisfied: sympy in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.9.0->pytorch-lightning>=1.6.4->donut-python) (1.12)
# Requirement already satisfied: networkx in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.9.0->pytorch-lightning>=1.6.4->donut-python) (3.1)
# Requirement already satisfied: jinja2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from torch>=1.9.0->pytorch-lightning>=1.6.4->donut-python) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pandas->datasets[vision]->donut-python) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pandas->datasets[vision]->donut-python) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pandas->datasets[vision]->donut-python) (2023.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ruamel.yaml->sconf>=0.2.3->donut-python) (0.2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from jinja2->torch>=1.9.0->pytorch-lightning>=1.6.4->donut-python) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from sympy->torch>=1.9.0->pytorch-lightning>=1.6.4->donut-python) (1.3.0)
# Requirement already satisfied: ipywidgets in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipywidgets) (8.12.3)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipywidgets) (5.14.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: pexpect>4.3 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: appnope in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
import argparse
import gradio as gr
import torch
from PIL import Image

from donut import DonutModel

# %%
def demo_process_vqa(input_img, question):
    global pretrained_model, task_prompt, task_name
    input_img = Image.fromarray(input_img)
    user_prompt = task_prompt.replace("{user_input}", question)
    output = pretrained_model.inference(input_img, prompt=user_prompt)["predictions"][0]
    return output


def demo_process(input_img):
    global pretrained_model, task_prompt, task_name
    input_img = Image.fromarray(input_img)
    output = pretrained_model.inference(image=input_img, prompt=task_prompt)["predictions"][0]
    return output

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--task", type=str, default="cord-v2")
parser.add_argument("--pretrained_path", type=str, default="naver-clova-ix/donut-base-finetuned-cord-v2")
args, left_argv = parser.parse_known_args()

task_name = args.task
if "docvqa" == task_name:
    task_prompt = "<s_docvqa><s_question>{user_input}</s_question><s_answer>"
else:  # rvlcdip, cord, ...
    task_prompt = f"<s_{task_name}>"

pretrained_model = DonutModel.from_pretrained(args.pretrained_path)
device = torch.device("cpu")
pretrained_model.to(device)


demo = gr.Interface(
    fn=demo_process_vqa if task_name == "docvqa" else demo_process,
    inputs=["image", "text"] if task_name == "docvqa" else "image",
    outputs="json",
    title=f"Donut 🍩 demonstration for `{task_name}` task",
)
demo.launch(debug=True)
# Out:
# /Users/randy/miniforge3/envs/donut-ocr-38/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3527.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
